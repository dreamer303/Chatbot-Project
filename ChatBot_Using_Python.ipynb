# %%
def tourism_bot():
    print("Welcome to Bangladesh TravelBot 🇧🇩! Ask me about visiting Bangladesh and trying local food.")
    print("Type 'exit' to end the conversation.\n")

    while True:
        user = input("You: ").lower()

        if "exit" in user:
            print("Bot: Have a great trip to Bangladesh! 👋")
            break

        elif "visa" in user or "need visa" in user or "entry requirements" in user:
            print("Bot: Most travelers need a visa. You can apply online or at a Bangladeshi embassy.")
        elif "How do I get a visa?" in user:
            print("The process typically involves applying through the Bangladesh Embassy or Consulate in your country, providing necessary documentation and fees.")
        elif "Can I get a visa on arrival?" in user:
            print("Some nationalities may be eligible for a visa on arrival, but this is not guaranteed. Check with the Bangladesh Embassy or Consulate for the latest information.")
        elif "best time" in user or "when to visit" in user:
            print("Bot: The best time to visit is from November to February—cooler and drier weather.")
        elif "how is the people" in user or "what about the people" in user:
            print("Bangladesh in one of the most densely populated country in the world. People of this country are most hospitable and friendly towards foreigners.If you go to a home, they will invite you and offer you food and drinks without any expectation from you. Unlike other countries, they won't ask for any money if you want to take a photograph of them.")
        elif "famous dishes" in user or "popular food" in user:
            print("Bot: You must try biryani, hilsa fish curry, panta ilish, kacchi biryani, and bhuna khichuri!")
        elif "spicy" in user:
            print("Bot: Bangladeshi food is often spicy, but many places can adjust spice levels.")
        elif "street food" in user or "famous street food" in user:
            print("Bot: Popular street foods include fuchka, chotpoti, and shingara. Just pick busy vendors for safety!")
        elif "vegetarian" in user or "vegan" in user:
            print("Bot: Yes, there are vegetarian dishes like dal, vegetable curry, and shobji khichuri.")
        elif "drink" in user or "popular drink" in user:
            print("Bot: Try Borhani (spiced yogurt drink), coconut water, and local tea!")
        elif "hilsa" in user:
            print("Bot: Absolutely! Hilsa (ilish) is Bangladesh's national fish and widely available.")
        elif "domestic flights" in user:
            print("Each day, 4-5 flights operate between Dhaka and Chittagong. For other cities, typically there is one flight per day in each direction from each airline.")
        elif "sweets" in user or "dessert" in user or "popular dessert" in user:
            print("Bot: Rasgulla, sandesh, chomchom, and mishti doi are must-try desserts.")
        elif "cost of visit" in user or "how costly is Bangladesh" in user:
            print("Bangladesh is a heaven for budget travelers. If you are really on a tight budget, you can get a room for only 300 BDT ($4 USD), get breakfast for 40 BDT, get a big meal for 150 BDT. If you want luxury , there are 5 star hotels and higher standard restaurants in big. ")
        elif "major cities" in user:
            print("The capital of Bangladesh is Dhaka. This is the most densely populated city in the world.Chittagong is the commercial city of Bangladesh. The largest sea-port of the country is located here. Other major cities are - Shylet, Khulna, Barishal, Rangpur and Rajshahi.")
        elif "local transportation" in user:
            print("Transportation options include rickshaws, buses, trains, and domestic flights. Be prepared for crowded conditions and potential delays. ")
        elif "language" in user:
            print("Bot: Bengali (Bangla) is the official language, but many people understand basic English.")
        elif "safety" in user or "is it safe" in user or "safety concerns" in user:
            print("Bot: Bangladesh is generally safe, especially in tourist areas.Be aware of potential risks such as petty theft, scams, and road accidents. Avoid walking alone at night in poorly lit areas, and be cautious of your belongings in crowded places. Just follow basic precautions.")
        elif "exchange money" in user or "Where can I exchange money?" in user:
            print("You can exchange money at banks, authorized money changers, and some hotels.")
        elif "best souvenirs to bring back from Bangladesh?" in user:
            print("Textiles: saris, panjabis, wristwatches, Sylhet tea: green, black or massala tea. Jute products: bags, mats, slippers. Handicrafts: pottery, bronze statuettes, bamboo products. Bangladeshi sweets and spices. Shellac caskets. Books about Bangladesh")
        elif "most popular sport" in user:
            print("Cricket is one of the most popular sports in Bangladesh. The Bangladesh national cricket team actively participates in international competitions and has many fans all over the country.")
        elif "general cost of things?" in user:
            print("The cost of living is generally lower than in many Western countries, but prices can vary depending on the location and type of establishment. ")
        elif "local currency" in user or "can I use credit cards" in user:
            print(" Bangladeshi Taka (BDT). Credit cards work in cities, but carry cash for rural areas and small vendors.")
        elif "top tourist attractions" in user or "good place for visiting" in user or "Recommend some place" in user:
            print("Sundarbans (mangrove forest), Cox’s Bazar (longest beach), Srimangal (tea gardens), and historical sites like Lalbagh Fort,Mahasthangarh and Paharpur Vihara.")
        elif "Is there anything else I should know?" in user:
            print("Be aware of cultural sensitivities, dress modestly when visiting religious sites, and be respectful of local customs. ")
        else:
            print("Bot: Sorry, I don't have an answer for that yet. Try asking something else about travel or food!")

tourism_bot()
